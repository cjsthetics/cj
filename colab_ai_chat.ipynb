# %% [markdown]
# <a href="https://colab.research.google.com/github/cjsthetics/cj/blob/main/colab_ai_chat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import ai as cj
def yujin():
  def nil():
    x = input('CJ:')
    while x != "bye":
      print("AI: " ,cj.generate_text(x))
      x = input('cj:')

    y=input('''AI: do you want to say bye?
type Y for yes and N for no : ''')
    if y=="Y":
      print("bye")
    elif y=="N":
      print("ok then...")
      nil()
    else:
      print('What?',y, 'Do you mean yes or no? ')
      y=input("Y or N?: ")
      if y == "Y":
        print("byee")
      else:
        print("ok then")
        nil()

  nil()
yujin()
# Out:
# CJ:hi
# AI:  Hi there! How can I help you today?
# cj:bye
# AI: do you want to say bye?
# type Y for yes and N for no : nad
# What? nad Do you mean yes or no?
# Y or N?: N
# ok then
# CJ:chiranjiv
# AI:  "Chiranjiv" (or "Chiranjeevi") is a multifaceted term, primarily of Sanskrit origin, with several significant meanings and associations, especially in Indian culture:
#
# 1.  **Meaning and Origin:**
#     *   **Sanskrit Origin:** The word "Chiranjiv" is derived from Sanskrit.
#     *   **Etymology:** It combines two words:
#         *   **"Chiram" (चिरम्):** meaning "long time," "forever."
#         *   **"Jeevi" (जीवी):** meaning "one who lives," "living."
#     *   **Overall Meaning:** Therefore, "Chiranjiv" literally means **"one who lives long," "immortal," or "ever-living."**
#
# 2.  **Cultural and Mythological Significance:**
# ...
